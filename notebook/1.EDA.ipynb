# %% [markdown]
# # Credit Card Churn
#
# ### Life cycle of Machine learning Project
#
# * Understanding the Problem Statement
# * Data Collection
# * Data Checks to perform
# * Exploratory aata analysis
# * Data Pre-Processing
# * Model Training
# * Choose best model

# %% [markdown]
# ## 1) Problem statement
#
# The bank is experiencing an increasing number of customers discontinuing their credit card services, which is a growing concern for management. Predicting customer churn in advance would enable the bank to take proactive measures, offer personalized services, and improve customer retention.

# %% [markdown]
# ## 2) Data Collection
#
# * Dataset Source - https://www.kaggle.com/datasets/anwarsan/credit-card-bank-churn

# %% [markdown]
# ### 2.1) Import Data and Required Packages
#
# #### Importing Pandas, Numpy, Matplotlib, Seaborn and Warnings Library.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Import the CSV Data as Pandas DataFrame

# %%
df = pd.read_csv("data/credit_card_churn.csv")

# %% [markdown]
# #### Show Top 5 Records

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %% [markdown]
# #### Shape of the dataset

# %%
df.shape
# Out:
# (10127, 23)

# %% [markdown]
# ### 2.2) Dataset Information
#
# * **Clientum**: Unique IDs of customers formed by a sequence of 9 digits, with a total of **10,127 unique customers** in the dataset.
# * **Attrition_Flag (Target Variable)**: Indicates whether the customer is an **Existing Customer** (current customer) or an **Attrited Customer** (churned customer).
# * **Customer_Age**: Represents the age of customers, ranging from **27 to 73 years**.
# * **Gender**: Coded as **F** for Female and **M** for Male.
# * **Dependent_count**: Represents the number of dependents associated with a customer.
# * **Education_Level**: Indicates the educational qualification of customers with **7 unique values** including **High School, Graduate, Uneducated, College, Post-graduate, Doctorate**, and **Unknown** (1,519 customers).
# * **Marital_Status**: Represents the marital status of customers, with **4 unique values**: **Married, Single, Divorced,** and **Unknown** (749 customers).
# * **Income_Category**: Represents the annual income category of the cardholder, including **Less than $40K, $40K - $60K, $60K - $80K, $80K - $120K, $120K+**, and **Unknown** (1,112 customers).
# * **Card_Category**: Indicates the type of credit card, with **4 unique values**: **Blue, Gold, Silver,** and **Platinum**.
# * **Months_on_book**: Represents the number of months a customer has held an account with the bank.
# * **Total_Relationship_Count**: Represents the number of products held by the customer.
# * **Months_Inactive_12_mon**: The number of months a customer has been inactive in the last **12 months**.
# * **Contacts_Count_12_mon**: The number of times a customer has contacted the bank in the last **12 months**.
# * **Credit_Limit**: Represents the credit limit on the credit card owned by the customer.
# * **Total_Revolving_Bal**: Represents the total revolving balance on the credit card.
# * **Avg_Open_To_Buy**: Represents the average available credit line over the last **12 months**.
# * **Total_Amt_Chng_Q4_Q1**: Represents the change in transaction amount from **Q4 to Q1**.
# * **Total_Trans_Amt**: Represents the total transaction amount in the last **12 months**.
# * **Total_Trans_Ct**: Represents the total transaction count in the last **12 months**.
# * **Total_Ct_Chng_Q4_Q1**: Represents the change in transaction count from **Q4 to Q1**.
# * **Avg_Utilization_Ratio**: Represents the average credit card utilization ratio.

# %% [markdown]
# ## 3) Data Checks to perform
#
# * Check Missing values
# * Check Duplicates
# * Check data type
# * Check the number of unique values of each column
# * Check statistics of data set
# * Check various categories present in the different categorical column

# %% [markdown]
# ### 3.1) Check Missing values

# %%
df.isnull().sum()
# Out:
# CLIENTNUM                                                                                                                             0
# Attrition_Flag                                                                                                                        0
# Customer_Age                                                                                                                          0
# Gender                                                                                                                                0
# Dependent_count                                                                                                                       0
# Education_Level                                                                                                                       0
# Marital_Status                                                                                                                        0
# ...

# %% [markdown]
# **There are no missing values in the dataset ???????**

# %%
for col in df.columns:
    print(f"{col}: {df[df[col] == 'Unknown'].shape[0]}")
# Out:
# CLIENTNUM: 0
# Attrition_Flag: 0
# Customer_Age: 0
# Gender: 0
# Dependent_count: 0
# Education_Level: 1519
# Marital_Status: 749
# Income_Category: 1112
# Card_Category: 0
# Months_on_book: 0
# Total_Relationship_Count: 0
# Months_Inactive_12_mon: 0
# Contacts_Count_12_mon: 0
# Credit_Limit: 0
# Total_Revolving_Bal: 0
# Avg_Open_To_Buy: 0
# Total_Amt_Chng_Q4_Q1: 0
# Total_Trans_Amt: 0
# Total_Trans_Ct: 0
# Total_Ct_Chng_Q4_Q1: 0
# Avg_Utilization_Ratio: 0
# Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1: 0
# Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2: 0

# %% [markdown]
# ### 3.2) Check Duplicates

# %%
df.duplicated().sum().item()
# Out:
# 0

# %% [markdown]
# **There are no duplicates values in the dataset**

# %% [markdown]
# ### 3.3) Check data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %% [markdown]
# ### 3.4) Checking the number of unique values of each column

# %%
df.nunique()
# Out:
# CLIENTNUM                                                                                                                             10127
# Attrition_Flag                                                                                                                            2
# Customer_Age                                                                                                                             45
# Gender                                                                                                                                    2
# Dependent_count                                                                                                                           6
# Education_Level                                                                                                                           7
# Marital_Status                                                                                                                            4
# ...

# %% [markdown]
# ### 3.5) Check statistics of the dataset

# %%
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %% [markdown]
# ### 3.5) Exploring Data

# %%
numeric_features = [col for col in df.columns if df[col].dtype != "O"]
categorical_features = [col for col in df.columns if df[col].dtype == "O"]

# %%
for cateCol in categorical_features:
    print(f"Categories in '{cateCol}' variable: {df[cateCol].unique()}")
# Out:
# Categories in 'Attrition_Flag' variable: ['Existing Customer' 'Attrited Customer']
# Categories in 'Gender' variable: ['M' 'F']
# Categories in 'Education_Level' variable: ['High School' 'Graduate' 'Uneducated' 'Unknown' 'College' 'Post-Graduate'
#  'Doctorate']
# Categories in 'Marital_Status' variable: ['Married' 'Single' 'Unknown' 'Divorced']
# Categories in 'Income_Category' variable: ['$60K - $80K' 'Less than $40K' '$80K - $120K' '$40K - $60K' '$120K +'
#  'Unknown']
# Categories in 'Card_Category' variable: ['Blue' 'Gold' 'Silver' 'Platinum']

# %%
print(f"We have {len(numeric_features)}: {numeric_features}")
print(f"We have {len(categorical_features)}: {categorical_features}")
# Out:
# We have 17: ['CLIENTNUM', 'Customer_Age', 'Dependent_count', 'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon', 'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal', 'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt', 'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2']
# We have 6: ['Attrition_Flag', 'Gender', 'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category']

# %% [markdown]
# ## 4) Exploring Data (Visualization)

# %%
def plot_distribution_and_boxplot(data, column_name):
    column_data = data[column_name]
    
    fig, axes = plt.subplots(1, 2, figsize=(14, 6))
    plt.subplots_adjust(wspace=0.5)
    fig.suptitle(f"{column_name}", fontsize=17)
    fig.text(0.5, 0.0016, 'Number of dependents', ha='center', fontsize=14)
    fig.text(0.00001, 0.5, 'Frequency', va='center', rotation='vertical', fontsize=14)

    axes[0].hist(column_data, bins=30, color='#1abc9c', edgecolor='black', alpha=0.7)
    axes[0].axvline(np.mean(column_data), color='#8C4F78', linestyle='--', label='Mean')
    axes[0].axvline(np.median(column_data), color='#000000', linestyle='-', label='Median')
    axes[0].set_title("Distribution", fontsize=15)
    axes[0].tick_params(labelsize=14)
    axes[0].legend()
    axes[0].set_xlabel(None)
    axes[0].set_ylabel(None)

    axes[1].boxplot(column_data, vert=False, patch_artist=True, 
                    boxprops=dict(facecolor='#FFC300', color='black'),
                    medianprops=dict(color='#000000', linewidth=2),
                    meanprops=dict(marker='o', markerfacecolor='#8C4F78', markersize=7))
    axes[1].set_title("Outliers Detection", fontsize=15)
    axes[1].tick_params(labelsize=14)
    axes[1].set_xlabel(None)
    axes[1].set_ylabel(None)

    fig.tight_layout()
    fig.show()

# %%
def plot_characteristics(df, column_name, sign, value):
    # Filter data based on the condition
    if sign == '>=':
        filtered_data = df[df[column_name] >= value]
    elif sign == '<=':
        filtered_data = df[df[column_name] <= value]
    elif sign == "==":
        filtered_data = df[df[column_name] == value]
    else:
        raise ValueError("Sign must be '>' or '<='")
    
    # Create the figure and axes
    fig, axes = plt.subplots(3, 2, figsize=(14, 6))
    plt.subplots_adjust(hspace=0.6, wspace=0.5)
    fig.suptitle(f"Characteristics of the {column_name}", fontsize=17)
    fig.text(0.5, 0.0016, 'Frequency', ha='center', fontsize=14)
    fig.text(0.00001, 0.5, 'Value', va='center', rotation='vertical', fontsize=14)
    sns.set_context('talk')

    # List of columns for which we are generating countplots
    columns = ['Attrition_Flag', 'Gender', 'Card_Category', 'Income_Category', 'Education_Level', 'Marital_Status']
    colors = ['#8C4F63', '#828C4F', '#8C4F63', '#828C4F', '#8C4F63', '#828C4F']
    
    # Generate countplots for each column in the list
    for i, col in enumerate(columns):
        ax = axes[i // 2, i % 2]
        
        # Filter and sort data for each column
        sorted_data = filtered_data[col].value_counts().index
        sns.countplot(y=filtered_data[col], order=sorted_data, color=colors[i], ax=ax)
        
        ax.tick_params(labelsize=7)
        ax.set(xlabel=None, ylabel=None)
        
        # Set title for each plot
        fontsize = 15
        ax.set_title(col.replace('_', ' ').title(), fontdict={'fontsize': fontsize})

    # Adjust layout for better spacing
    fig.tight_layout()
    fig.show()

# %% [markdown]
# ### 4.1) Numerical Data

# %% [markdown]
# #### 4.1.1) Customer Age Analysis

# %%
plot_distribution_and_boxplot(df, 'Customer_Age')

# %%
plot_characteristics(df, "Customer_Age", ">=", 70)

# %% [markdown]
# #### 4.1.2) Dependent Count Analysis

# %%
plot_distribution_and_boxplot(df, "Dependent_count")

# %% [markdown]
# #### 4.1.3) Months on book Analysis

# %%
plot_distribution_and_boxplot(df, "Months_on_book")

# %%
plot_characteristics(df, "Months_on_book", "<=", 18)

# %%
plot_characteristics(df, "Months_on_book", ">=", 54)

# %% [markdown]
# #### 4.1.4) Total Relationship Count Analysis

# %%
plot_distribution_and_boxplot(df, "Total_Relationship_Count")

# %% [markdown]
# #### 4.1.5) Month Inactive 12 mon Analysis

# %%
plot_distribution_and_boxplot(df, "Months_Inactive_12_mon")

# %%
plot_characteristics(df, "Months_Inactive_12_mon", "==", 0)

# %% [markdown]
# #### 4.1.6) Contacts Count 12 mon Analysis

# %%
plot_distribution_and_boxplot(df, "Contacts_Count_12_mon")

# %%
plot_characteristics(df, "Contacts_Count_12_mon", "==", 0)

# %% [markdown]
# #### 4.1.7) Credit Limit Analysis

# %%
plot_distribution_and_boxplot(df, "Credit_Limit")

# %%
plot_characteristics(df, "Credit_Limit", ">=", 23000)

# %% [markdown]
# #### 4.1.8) Total Revolving Bal Analysis

# %%
plot_distribution_and_boxplot(df, "Total_Revolving_Bal")

# %% [markdown]
# #### 4.1.9) Average Open To Buy Analysis

# %%
plot_distribution_and_boxplot(df, "Avg_Open_To_Buy")

# %%
plot_characteristics(df, "Avg_Open_To_Buy", ">=", 22500)

# %% [markdown]
# #### 4.1.10) Total Amt Chng Q4 Q1 Analysis

# %%
plot_distribution_and_boxplot(df, "Total_Amt_Chng_Q4_Q1")

# %%
plot_characteristics(df, "Total_Amt_Chng_Q4_Q1", "<=", 0.3)

# %%
plot_characteristics(df, "Total_Amt_Chng_Q4_Q1", ">=", 1.2)

# %% [markdown]
# #### 4.1.11) Total Trans Amt Analysis

# %%
plot_distribution_and_boxplot(df, "Total_Trans_Amt")

# %%
plot_characteristics(df, "Total_Trans_Amt", ">=", 8000)

# %% [markdown]
# #### 4.1.12) Total Trans Ct Analysis

# %%
plot_distribution_and_boxplot(df, "Total_Trans_Ct")

# %% [markdown]
# #### 4.1.13) Total Ct Chng Q4 Q1 Analysis

# %%
plot_distribution_and_boxplot(df, "Total_Ct_Chng_Q4_Q1")

# %% [markdown]
# #### 4.1.14) Avg_Utilization_Ratio Analysis

# %%
plot_distribution_and_boxplot(df, "Avg_Utilization_Ratio")

# %% [markdown]
# ### 4.2) Categorical Data

# %% [markdown]
# #### 4.2.1) Churn Analysis

# %%
# Set figure size and style
plt.figure(figsize=(12, 6), dpi=80)
sns.set_style("darkgrid", {"axes.facecolor": ".9"})
sns.set_context('poster')

# Total count for percentage calculations
total = len(df['Attrition_Flag'])

# Formatting function for percentage and count
def my_fmt(x):
    return '{:.2f}%\n({:.0f})'.format(x, total * x / 100)

# Pie chart for churn frequency
plt.pie(df['Attrition_Flag'].value_counts().values,
        labels=df['Attrition_Flag'].value_counts().index,
        pctdistance=0.6,
        shadow=True,
        labeldistance=1.1,
        radius=1.5,
        explode=[0.1, 0], 
        colors=['#4E8C77', '#EAD45A'],
        textprops={'fontsize': 14},
        autopct=my_fmt)

# Title and layout adjustments
plt.title('Frequency of Churn', fontsize=17)
plt.axis('equal')  # Ensure pie chart is circular
plt.show()

# %%
def plot_pie_count_distribution(df, column_name):
    fig, ax = plt.subplots(1, 2, figsize=(20, 6))
    plt.subplots_adjust(wspace=0.7)
    sns.set_style("darkgrid", {"axes.facecolor": ".9"})
    sns.set_context('talk')

    # Total count for percentage calculation
    total = len(df[column_name])

    def my_fmt(x):
        return '{:.2f}%\n({:.0f})'.format(x, total * x / 100)

    # Pie chart for gender distribution
    ax[0].pie(df[column_name].value_counts().values,
              labels=df[column_name].value_counts().index,
              pctdistance=0.5,
              shadow=True,
              labeldistance=1.1,
              radius=1.5,
              colors=['#4E8C77','#C70039','#1abc9c','#DAF7A6','#FFC300','#FF5733','#C70039','#900C3F'],
              startangle=85,
              textprops={'fontsize': 7},
              autopct=my_fmt)

    ax[0].set_title(f'Distribution of {column_name}', fontsize=17)
    ax[0].axis('equal')

    # Count plot for Gender vs Churn
    sns.countplot(data=df, x=column_name, hue="Attrition_Flag",
                  palette=['#4F788C', '#8C4F78'],
                  order=df[column_name].value_counts().index, ax=ax[1])

    plt.setp(ax[1].get_legend().get_title(), fontsize='10')
    plt.setp(ax[1].get_legend().get_texts(), fontsize='10')
    ax[1].legend(bbox_to_anchor=(1, 1))
    ax[1].set(xlabel=None, ylabel=None)
    ax[1].tick_params(labelsize=7)
    ax[1].set_title(f'{column_name} vs Churn', fontsize=17)

    # Adjust layout
    fig.tight_layout()
    plt.show()

# %% [markdown]
# #### 4.2.2) Gender Analysis

# %%
plot_pie_count_distribution(df, "Gender")

# %% [markdown]
# #### 4.2.3) Education Level Analysis

# %%
plot_pie_count_distribution(df, "Education_Level")

# %% [markdown]
# #### 4.2.4) Marital Status Analysis

# %%
plot_pie_count_distribution(df, "Marital_Status")

# %% [markdown]
# #### 4.2.5) Income Category Analysis

# %%
plot_pie_count_distribution(df, "Income_Category")

# %% [markdown]
# #### 4.2.6) Card Category Analysis

# %%
plot_pie_count_distribution(df, "Card_Category")

# %% [markdown]
# ### 4.3) Relationship between Numerical Columns

# %%
# sns.pairplot(data=df, hue='Attrition_Flag', corner=True, diag_kind="hist")
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### 4.4) Correlation

# %%
df["Attrition_Flag"] = np.where(df["Attrition_Flag"] == "Attrited Customer", 1, 0)
df.drop(["Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1", "Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2"], axis=1, inplace=True)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df[numeric_features[:-2]].corr(), annot=True, fmt=".1f",  linewidth=1)

plt.show()

# %%
categorical_features
# Out:
# ['Attrition_Flag',
#  'Gender',
#  'Education_Level',
#  'Marital_Status',
#  'Income_Category',
#  'Card_Category']
